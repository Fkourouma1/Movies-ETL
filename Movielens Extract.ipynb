# %%
import pandas as pd

# %%
file_dir = '/Users/fatoumatakourouma/desktop/Class Folder/movies_metadata'

# %%
movies_metadata = pd.read_csv(f'{file_dir}movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{file_dir}ratings.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 movies_metadata = pd.read_csv(f'{file_dir}movies_metadata.csv', low_memory=False)
#       2 ratings = pd.read_csv(f'{file_dir}ratings.csv')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
movies_metadata = pd.read_csv('movies_metadata.csv', low_memory=False)
ratings= pd.read_csv('ratings.csv')

# %%
movies_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
ratings.tail()
# Out:
#           userId  movieId  rating   timestamp
# 26024284  270896    58559     5.0  1257031564
# 26024285  270896    60069     5.0  1257032032
# 26024286  270896    63082     4.5  1257031764
# 26024287  270896    64957     4.5  1257033990
# 26024288  270896    71878     2.0  1257031858

# %%
movies_metadata.tail()
# Out:
#        adult belongs_to_collection budget  \
# 45461  False                   NaN      0
# 45462  False                   NaN      0
# 45463  False                   NaN      0
# 45464  False                   NaN      0
# 45465  False                   NaN      0
#
#                                                   genres  \
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# ...

# %%
movies_metadata.sample(n=5)
# Out:
#        adult belongs_to_collection budget  \
# 40505  False                   NaN      0
# 14027  False                   NaN      0
# 26906  False                   NaN      0
# 826    False                   NaN      0
# 41473  False                   NaN      0
#
#                                                   genres  \
# 40505                [{'id': 99, 'name': 'Documentary'}]
# 14027  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 26906  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 826    [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 41473                     [{'id': 35, 'name': 'Comedy'}]
#
#                      homepage      id    imdb_id original_language  \
# 40505                     NaN  337641  tt4336182                en
# 14027                     NaN  128856  tt0407008                de
# 26906                     NaN   29799  tt0114192                fr
# 826                       NaN   36266  tt0112767                vi
# ...

# %%
ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 14115025  146645      533     3.0   842092477
# 21109158  219329     8937     5.0  1125966221
# 1206761    12399     2108     3.5  1348878376
# 1263225    12962      575     1.0  1032284458
# 3793400    39587      265     4.0   912581857
